# %%
traindata = pd.read_csv("/home/dockeruser/data/titanic/train.csv")
testdata = pd.read_csv("/home/dockeruser/data/titanic/test.csv")

# %%
#result = sm.OLS.from_formula("Survived ~ Pclass + Sex + Embarked +SibSp + Parch", data=traindata)
result = sm.OLS.from_formula("Survived ~ Fare", data=traindata)

# %%
fits = result.fit()

# %%
fits.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:               Survived   R-squared:                       0.066
# Model:                            OLS   Adj. R-squared:                  0.065
# Method:                 Least Squares   F-statistic:                     63.03
# Date:                Sat, 22 Jul 2017   Prob (F-statistic):           6.12e-15
# Time:                        16:31:48   Log-Likelihood:                -591.44
# No. Observations:                 891   AIC:                             1187.
# Df Residuals:                     889   BIC:                             1196.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.3027      0.019     16.114      0.000       0.266       0.340
# ...

# %%
asdf = traindata[["Survived", "Pclass", "Fare"]]

# %%
asdf.describe()
# Out:
#          Survived      Pclass        Fare
# count  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   32.204208
# std      0.486592    0.836071   49.693429
# min      0.000000    1.000000    0.000000
# 25%      0.000000    2.000000    7.910400
# 50%      0.000000    3.000000   14.454200
# 75%      1.000000    3.000000   31.000000
# max      1.000000    3.000000  512.329200

# %%
traindata[["Survived", "Sex", "Embarked"]]
# Out:
#      Survived     Sex Embarked
# 0           0    male        S
# 1           1  female        C
# 2           1  female        S
# 3           1  female        S
# 4           0    male        S
# 5           0    male        Q
# 6           0    male        S
# 7           0    male        S
# 8           1  female        S
# 9           1  female        C
# 10          1  female        S
# 11          1  female        S
# 12          0    male        S
# 13          0    male        S
# 14          0  female        S
# 15          1  female        S
# 16          0    male        Q
# 17          1    male        S
# 18          0  female        S
# 19          1  female        C
# 20          0    male        S
# 21          1    male        S
# 22          1  female        Q
# 23          1    male        S
# 24          0  female        S
# 25          1  female        S
# 26          0    male        C
# 27          0    male        S
# 28          1  female        Q
# ...
